# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('marketing_customer_analysis.csv')
display(file1)
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
file1.shape
# Out:
# (10910, 26)

# %%
new_names = {
    'Customer': 'customer_id',
    'Unnamed: 0': 'unnamed: 0',
    'State': 'state',
    'Customer Lifetime Value': 'customer_lifetime_value',
    'Response': 'response',
    'Coverage': 'coverage',
    'Education': 'education',
    'Effective To Date': 'effective_to_date',
    'EmploymentStatus': 'employment_status',
    'Gender': 'gender',
    'Number of Open Complaints': 'num_open_complaints',
    'Number of Policies': 'num_policies',
    'Policy Type': 'policy_type',
    'Policy': 'policy',
    'Renew Offer Type': 'renew_offer_type',
    'Sales Channel': 'sales_channel',
    'Total Claim Amount': 'total_claim_amount',
    'Vehicle Class': 'vehicle_class',
    'Vehicle Size': 'vehicle_size',
    'Vehicle Type': 'vehicle_type'
}

file1 = file1.rename(columns=new_names)
display(file1.columns)
# Out:
# Index(['0', 'customer_id', 'state', 'customer_lifetime_value', 'response',
#        'coverage', 'education', 'effective_to_date', 'employment_status',
#        'gender', 'Income', 'Location Code', 'Marital Status',
#        'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'num_open_complaints', 'num_policies',
#        'policy_type', 'policy', 'renew_offer_type', 'sales_channel',
#        'total_claim_amount', 'vehicle_class', 'vehicle_size', 'vehicle_type',
#        'month'],
#       dtype='object')

# %%
num_cols = file1.select_dtypes(include=['int64', 'float64']).columns
display(num_cols)
# Out:
# Index(['0', 'customer_lifetime_value', 'Income', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'num_open_complaints', 'num_policies', 'total_claim_amount'],
#       dtype='object')

# %%
obj_cols = file1.select_dtypes(include=['object']).columns
display(obj_cols)
# Out:
# Index(['customer_id', 'state', 'response', 'coverage', 'education',
#        'employment_status', 'gender', 'Location Code', 'Marital Status',
#        'policy_type', 'policy', 'renew_offer_type', 'sales_channel',
#        'vehicle_class', 'vehicle_size', 'vehicle_type'],
#       dtype='object')

# %%
display(file1.isna())
file1.dropna(inplace=True)
display(file1)
# Out:
#            0  customer_id  state  customer_lifetime_value  response  coverage  \
# 0      False        False  False                    False     False     False
# 1      False        False  False                    False     False     False
# 2      False        False  False                    False     False     False
# 3      False        False  False                    False     False     False
# 4      False        False  False                    False     False     False
# ...      ...          ...    ...                      ...       ...       ...
# 10905  False        False  False                    False     False     False
# 10906  False        False  False                    False     False     False
# 10907  False        False  False                    False     False     False
# 10908  False        False  False                    False     False     False
# 10909  False        False   True                    False      True     False
#
#        education  effective_to_date  employment_status  gender  ...  \
# 0          False              False              False   False  ...
# 1          False              False              False   False  ...
# 2          False              False              False   False  ...
# 3          False              False              False   False  ...
# 4          False              False              False   False  ...
# ...          ...                ...                ...     ...  ...
# 10905      False              False              False   False  ...
# 10906      False              False              False   False  ...
# 10907      False              False              False   False  ...
# 10908      False              False              False   False  ...
# 10909      False              False              False   False  ...
#
#        num_open_complaints  num_policies  policy_type  policy  \
# 0                    False         False        False   False
# 1                    False         False        False   False
# 2                    False         False        False   False
# 3                    False         False        False   False
# 4                     True         False        False   False
# ...                    ...           ...          ...     ...
# 10905                 True         False        False   False
# 10906                False         False        False   False
# 10907                False         False        False   False
# 10908                False         False        False   False
# 10909                False         False        False   False
#
#        renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0                 False          False               False          False
# 1                 False          False               False          False
# 2                 False          False               False          False
# 3                 False          False               False          False
# 4                 False          False               False          False
# ...                 ...            ...                 ...            ...
# 10905             False          False               False          False
# 10906             False          False               False          False
# 10907             False          False               False          False
# 10908             False          False               False          False
# 10909             False          False               False          False
#
#        vehicle_size  vehicle_type
# 0             False          True
# 1             False          True
# 2             False         False
# 3             False         False
# 4             False          True
# ...             ...           ...
# 10905         False         False
# 10906         False         False
# 10907         False          True
# 10908         False         False
# 10909         False          True
#
# [10910 rows x 26 columns]
#            0 customer_id       state  customer_lifetime_value response  \
# 2          2     LZ68649  Washington             14947.917300       No
# 3          3     XL78013      Oregon             22332.439460      Yes
# 10        10     HG93801     Arizona              5154.764074       No
# 13        13     KR82385  California              5454.587929       No
# 16        16     FH51383  California              5326.677654       No
# ...      ...         ...         ...                      ...      ...
# 10902  10902     PP30874  California              3579.023825       No
# 10903  10903     SU71163     Arizona              2771.663013       No
# 10904  10904     QI63521      Nevada             19228.463620       No
# 10906  10906     KX53892      Oregon              5259.444853       No
# 10908  10908     WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employment_status  \
# 2         Basic              Bachelor           2/10/11          Employed
# 3      Extended               College           1/11/11          Employed
# 10     Extended  High School or Below            1/2/11          Employed
# 13        Basic                Master           1/26/11          Employed
# 16        Basic  High School or Below            2/7/11          Employed
# ...         ...                   ...               ...               ...
# 10902  Extended  High School or Below           1/24/11          Employed
# 10903     Basic               College            1/7/11          Employed
# 10904     Basic  High School or Below           2/24/11        Unemployed
# 10906     Basic               College            1/6/11          Employed
# 10908   Premium               College           2/13/11          Employed
#
#       gender  ...  num_open_complaints num_policies     policy_type  \
# 2          M  ...                  0.0            2   Personal Auto
# 3          M  ...                  0.0            2  Corporate Auto
# 10         M  ...                  0.0            1  Corporate Auto
# 13         M  ...                  0.0            4   Personal Auto
# 16         F  ...                  0.0            6   Personal Auto
# ...      ...  ...                  ...          ...             ...
# 10902      F  ...                  2.0            1   Personal Auto
# 10903      M  ...                  4.0            1   Personal Auto
# 10904      M  ...                  0.0            2   Personal Auto
# 10906      F  ...                  0.0            6   Personal Auto
# 10908      F  ...                  4.0            6   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 10     Corporate L3            Offer2         Branch          442.521087
# 13      Personal L3            Offer4    Call Center          331.200000
# 16      Personal L3            Offer4    Call Center          300.528579
# ...             ...               ...            ...                 ...
# 10902   Personal L2            Offer2          Agent          655.200000
# 10903   Personal L2            Offer2         Branch          355.200000
# 10904   Personal L2            Offer1         Branch          897.600000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10908   Personal L1            Offer1         Branch          618.288849
#
#        vehicle_class vehicle_size vehicle_type
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 10               SUV        Large            A
# 13      Two-Door Car      Medsize            A
# 16      Two-Door Car        Large            A
# ...              ...          ...          ...
# 10902  Four-Door Car      Medsize            A
# 10903   Two-Door Car      Medsize            A
# 10904     Luxury SUV      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10908            SUV      Medsize            A
#
# [4543 rows x 26 columns]

# %%
file1['effective_to_date'] = pd.to_datetime(file1['effective_to_date'])
file1['month'] = file1['effective_to_date'].dt.month
q1_data = file1[(file1['month'] >= 1) & (file1['month'] <= 3)]
display(q1_data)
display(file1)
# Out:
#            0 customer_id       state  customer_lifetime_value response  \
# 2          2     LZ68649  Washington             14947.917300       No
# 3          3     XL78013      Oregon             22332.439460      Yes
# 10        10     HG93801     Arizona              5154.764074       No
# 13        13     KR82385  California              5454.587929       No
# 16        16     FH51383  California              5326.677654       No
# ...      ...         ...         ...                      ...      ...
# 10902  10902     PP30874  California              3579.023825       No
# 10903  10903     SU71163     Arizona              2771.663013       No
# 10904  10904     QI63521      Nevada             19228.463620       No
# 10906  10906     KX53892      Oregon              5259.444853       No
# 10908  10908     WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employment_status  \
# 2         Basic              Bachelor        2011-02-10          Employed
# 3      Extended               College        2011-01-11          Employed
# 10     Extended  High School or Below        2011-01-02          Employed
# 13        Basic                Master        2011-01-26          Employed
# 16        Basic  High School or Below        2011-02-07          Employed
# ...         ...                   ...               ...               ...
# 10902  Extended  High School or Below        2011-01-24          Employed
# 10903     Basic               College        2011-01-07          Employed
# 10904     Basic  High School or Below        2011-02-24        Unemployed
# 10906     Basic               College        2011-01-06          Employed
# 10908   Premium               College        2011-02-13          Employed
#
#       gender  ...  num_policies     policy_type        policy  \
# 2          M  ...             2   Personal Auto   Personal L3
# 3          M  ...             2  Corporate Auto  Corporate L3
# 10         M  ...             1  Corporate Auto  Corporate L3
# 13         M  ...             4   Personal Auto   Personal L3
# 16         F  ...             6   Personal Auto   Personal L3
# ...      ...  ...           ...             ...           ...
# 10902      F  ...             1   Personal Auto   Personal L2
# 10903      M  ...             1   Personal Auto   Personal L2
# 10904      M  ...             2   Personal Auto   Personal L2
# 10906      F  ...             6   Personal Auto   Personal L3
# 10908      F  ...             6   Personal Auto   Personal L1
#
#        renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 2                Offer3    Call Center          480.000000            SUV
# 3                Offer2         Branch          484.013411  Four-Door Car
# 10               Offer2         Branch          442.521087            SUV
# 13               Offer4    Call Center          331.200000   Two-Door Car
# 16               Offer4    Call Center          300.528579   Two-Door Car
# ...                 ...            ...                 ...            ...
# 10902            Offer2          Agent          655.200000  Four-Door Car
# 10903            Offer2         Branch          355.200000   Two-Door Car
# 10904            Offer1         Branch          897.600000     Luxury SUV
# 10906            Offer2         Branch          273.018929  Four-Door Car
# 10908            Offer1         Branch          618.288849            SUV
#
#        vehicle_size vehicle_type month
# 2           Medsize            A     2
# 3           Medsize            A     1
# 10            Large            A     1
# 13          Medsize            A     1
# 16            Large            A     2
# ...             ...          ...   ...
# 10902       Medsize            A     1
# 10903       Medsize            A     1
# 10904       Medsize            A     2
# 10906       Medsize            A     1
# 10908       Medsize            A     2
#
# [4543 rows x 27 columns]
#            0 customer_id       state  customer_lifetime_value response  \
# 2          2     LZ68649  Washington             14947.917300       No
# 3          3     XL78013      Oregon             22332.439460      Yes
# 10        10     HG93801     Arizona              5154.764074       No
# 13        13     KR82385  California              5454.587929       No
# 16        16     FH51383  California              5326.677654       No
# ...      ...         ...         ...                      ...      ...
# 10902  10902     PP30874  California              3579.023825       No
# 10903  10903     SU71163     Arizona              2771.663013       No
# 10904  10904     QI63521      Nevada             19228.463620       No
# 10906  10906     KX53892      Oregon              5259.444853       No
# 10908  10908     WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employment_status  \
# 2         Basic              Bachelor        2011-02-10          Employed
# 3      Extended               College        2011-01-11          Employed
# 10     Extended  High School or Below        2011-01-02          Employed
# 13        Basic                Master        2011-01-26          Employed
# 16        Basic  High School or Below        2011-02-07          Employed
# ...         ...                   ...               ...               ...
# 10902  Extended  High School or Below        2011-01-24          Employed
# 10903     Basic               College        2011-01-07          Employed
# 10904     Basic  High School or Below        2011-02-24        Unemployed
# 10906     Basic               College        2011-01-06          Employed
# 10908   Premium               College        2011-02-13          Employed
#
#       gender  ...  num_policies     policy_type        policy  \
# 2          M  ...             2   Personal Auto   Personal L3
# 3          M  ...             2  Corporate Auto  Corporate L3
# 10         M  ...             1  Corporate Auto  Corporate L3
# 13         M  ...             4   Personal Auto   Personal L3
# 16         F  ...             6   Personal Auto   Personal L3
# ...      ...  ...           ...             ...           ...
# 10902      F  ...             1   Personal Auto   Personal L2
# 10903      M  ...             1   Personal Auto   Personal L2
# 10904      M  ...             2   Personal Auto   Personal L2
# 10906      F  ...             6   Personal Auto   Personal L3
# 10908      F  ...             6   Personal Auto   Personal L1
#
#        renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 2                Offer3    Call Center          480.000000            SUV
# 3                Offer2         Branch          484.013411  Four-Door Car
# 10               Offer2         Branch          442.521087            SUV
# 13               Offer4    Call Center          331.200000   Two-Door Car
# 16               Offer4    Call Center          300.528579   Two-Door Car
# ...                 ...            ...                 ...            ...
# 10902            Offer2          Agent          655.200000  Four-Door Car
# 10903            Offer2         Branch          355.200000   Two-Door Car
# 10904            Offer1         Branch          897.600000     Luxury SUV
# 10906            Offer2         Branch          273.018929  Four-Door Car
# 10908            Offer1         Branch          618.288849            SUV
#
#        vehicle_size vehicle_type month
# 2           Medsize            A     2
# 3           Medsize            A     1
# 10            Large            A     1
# 13          Medsize            A     1
# 16            Large            A     2
# ...             ...          ...   ...
# 10902       Medsize            A     1
# 10903       Medsize            A     1
# 10904       Medsize            A     2
# 10906       Medsize            A     1
# 10908       Medsize            A     2
#
# [4543 rows x 27 columns]

# %%
#ROUND 3 STARTS HERE

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4543 entries, 2 to 10908
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   0                              4543 non-null   int64
#  1   customer_id                    4543 non-null   object
#  2   state                          4543 non-null   object
#  3   customer_lifetime_value        4543 non-null   float64
#  4   response                       4543 non-null   object
#  5   coverage                       4543 non-null   object
#  6   education                      4543 non-null   object
#  7   effective_to_date              4543 non-null   datetime64[ns]
#  8   employment_status              4543 non-null   object
#  9   gender                         4543 non-null   object
#  10  Income                         4543 non-null   int64
#  11  Location Code                  4543 non-null   object
#  12  Marital Status                 4543 non-null   object
#  13  Monthly Premium Auto           4543 non-null   int64
#  14  Months Since Last Claim        4543 non-null   float64
#  15  Months Since Policy Inception  4543 non-null   int64
#  16  num_open_complaints            4543 non-null   float64
#  17  num_policies                   4543 non-null   int64
#  18  policy_type                    4543 non-null   object
#  19  policy                         4543 non-null   object
#  20  renew_offer_type               4543 non-null   object
#  21  sales_channel                  4543 non-null   object
#  22  total_claim_amount             4543 non-null   float64
#  23  vehicle_class                  4543 non-null   object
#  24  vehicle_size                   4543 non-null   object
#  25  vehicle_type                   4543 non-null   object
#  26  month                          4543 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(6), object(16)
# memory usage: 993.8+ KB

# %%
file1.describe()
# Out:
#                   0  customer_lifetime_value        Income  \
# count   4543.000000              4543.000000   4543.000000
# mean    5540.241250              8033.714059  37453.033238
# std     3149.146534              6959.529443  30257.399536
# min        2.000000              1904.000852      0.000000
# 25%     2884.000000              4039.089902      0.000000
# 50%     5549.000000              5846.520588  34455.000000
# 75%     8283.000000              8936.596938  61560.000000
# max    10908.000000             83325.381190  99961.000000
#
#        Monthly Premium Auto  Months Since Last Claim  \
# count           4543.000000              4543.000000
# mean              93.773278                15.111820
# std               35.093661                10.157925
# min               61.000000                 0.000000
# 25%               69.000000                 6.000000
# 50%               83.000000                14.000000
# 75%              110.000000                23.000000
# max              298.000000                35.000000
#
#        Months Since Policy Inception  num_open_complaints  num_policies  \
# count                    4543.000000          4543.000000   4543.000000
# mean                       48.153863             0.386309      2.980189
# std                        28.146904             0.907553      2.390362
# min                         0.000000             0.000000      1.000000
# 25%                        24.000000             0.000000      1.000000
# 50%                        47.000000             0.000000      2.000000
# 75%                        72.000000             0.000000      4.000000
# max                        99.000000             5.000000      9.000000
#
#        total_claim_amount        month
# count         4543.000000  4543.000000
# mean           436.477525     1.469734
# std            295.026990     0.499138
# min              0.099007     1.000000
# 25%            265.686145     1.000000
# 50%            384.000000     1.000000
# 75%            552.000000     2.000000
# max           2893.239678     2.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
counts = file1['response'].value_counts()
counts.plot(kind='bar', color='blue')
plt.xlabel('Response')
plt.ylabel('Number of Occurrences')
plt.title('Total Number of Yes and No Responses')
plt.show()

# %%
display(file1)
# Out:
#            0 customer_id       state  customer_lifetime_value response  \
# 2          2     LZ68649  Washington             14947.917300       No
# 3          3     XL78013      Oregon             22332.439460      Yes
# 10        10     HG93801     Arizona              5154.764074       No
# 13        13     KR82385  California              5454.587929       No
# 16        16     FH51383  California              5326.677654       No
# ...      ...         ...         ...                      ...      ...
# 10902  10902     PP30874  California              3579.023825       No
# 10903  10903     SU71163     Arizona              2771.663013       No
# 10904  10904     QI63521      Nevada             19228.463620       No
# 10906  10906     KX53892      Oregon              5259.444853       No
# 10908  10908     WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employment_status  \
# 2         Basic              Bachelor        2011-02-10          Employed
# 3      Extended               College        2011-01-11          Employed
# 10     Extended  High School or Below        2011-01-02          Employed
# 13        Basic                Master        2011-01-26          Employed
# 16        Basic  High School or Below        2011-02-07          Employed
# ...         ...                   ...               ...               ...
# 10902  Extended  High School or Below        2011-01-24          Employed
# 10903     Basic               College        2011-01-07          Employed
# 10904     Basic  High School or Below        2011-02-24        Unemployed
# 10906     Basic               College        2011-01-06          Employed
# 10908   Premium               College        2011-02-13          Employed
#
#       gender  ...  num_policies     policy_type        policy  \
# 2          M  ...             2   Personal Auto   Personal L3
# 3          M  ...             2  Corporate Auto  Corporate L3
# 10         M  ...             1  Corporate Auto  Corporate L3
# 13         M  ...             4   Personal Auto   Personal L3
# 16         F  ...             6   Personal Auto   Personal L3
# ...      ...  ...           ...             ...           ...
# 10902      F  ...             1   Personal Auto   Personal L2
# 10903      M  ...             1   Personal Auto   Personal L2
# 10904      M  ...             2   Personal Auto   Personal L2
# 10906      F  ...             6   Personal Auto   Personal L3
# 10908      F  ...             6   Personal Auto   Personal L1
#
#        renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 2                Offer3    Call Center          480.000000            SUV
# 3                Offer2         Branch          484.013411  Four-Door Car
# 10               Offer2         Branch          442.521087            SUV
# 13               Offer4    Call Center          331.200000   Two-Door Car
# 16               Offer4    Call Center          300.528579   Two-Door Car
# ...                 ...            ...                 ...            ...
# 10902            Offer2          Agent          655.200000  Four-Door Car
# 10903            Offer2         Branch          355.200000   Two-Door Car
# 10904            Offer1         Branch          897.600000     Luxury SUV
# 10906            Offer2         Branch          273.018929  Four-Door Car
# 10908            Offer1         Branch          618.288849            SUV
#
#        vehicle_size vehicle_type month
# 2           Medsize            A     2
# 3           Medsize            A     1
# 10            Large            A     1
# 13          Medsize            A     1
# 16            Large            A     2
# ...             ...          ...   ...
# 10902       Medsize            A     1
# 10903       Medsize            A     1
# 10904       Medsize            A     2
# 10906       Medsize            A     1
# 10908       Medsize            A     2
#
# [4543 rows x 27 columns]

# %%
file1['sales_channel'].value_counts()
# Out:
# Agent          1751
# Branch         1246
# Call Center     883
# Web             663
# Name: sales_channel, dtype: int64

# %%
channel_counts = file1['sales_channel'].value_counts()
channel_counts.plot(kind='bar', color='blue')
plt.xlabel('Sales Channel')
plt.ylabel('Count')
plt.title('Type of Sales Channel')
plt.show()

# %%
file1['total_claim_amount'].plot(kind='hist', color='blue', bins=5)
plt.xlabel('Total Claim Amount')
plt.ylabel('Count')
plt.title('Total Claim Amount')
plt.show()

# %%
pd.set_option('display.max_columns', None)
file1['Income'].plot(kind='hist', color='blue', bins=5)
plt.xlabel('Total Income')
plt.ylabel('Count')
plt.title('Total Income Amount')
plt.show()
